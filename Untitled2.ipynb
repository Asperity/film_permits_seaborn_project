# %%
import pandas as pd
import seaborn as sns

raw_data = pd.read_csv("Film_Permits_20260713.csv")

# %%
df = raw_data

# %%
df[['StartDateTime', 'ParkingHeld']]
# Out:
#                 StartDateTime  \
# 0      04/11/2026 06:30:00 AM
# 1      04/10/2026 06:00:00 AM
# 2      04/10/2026 01:00:00 PM
# 3      04/10/2026 09:30:00 AM
# 4                         NaN
# ...                       ...
# 17940  02/11/2023 06:00:00 AM
# 17941  02/10/2023 06:00:00 AM
# 17942  02/09/2023 06:00:00 AM
# 17943  02/08/2023 06:00:00 AM
# 17944  09/16/2025 08:00:00 AM
#
#                                              ParkingHeld
# 0         WEST   43 STREET between 6 AVENUE and BROADWAY
# 1      NORTH HENRY STREET between GREENPOINT AVENUE a...
# 2      PARK AVENUE between VANDERBILT AVENUE and CLIN...
# 3      WEST   24 STREET between 6 AVENUE and 5 AVENUE...
# 4      23RD ST  between HOYT AVE N  and HOYT AVE S , ...
# ...                                                  ...
# 17940   WEST   58 STREET between 10 AVENUE and 11 AVENUE
# 17941   WEST   58 STREET between 10 AVENUE and 11 AVENUE
# 17942   WEST   58 STREET between 10 AVENUE and 11 AVENUE
# ...

# %%
df.dropna(subset=['StartDateTime', 'ParkingHeld'])
# Out:
#        EventID        EventType           StartDateTime  \
# 0       930405  Shooting Permit  04/11/2026 06:30:00 AM
# 1       930051  Shooting Permit  04/10/2026 06:00:00 AM
# 2       931097  Shooting Permit  04/10/2026 01:00:00 PM
# 3       931878  Shooting Permit  04/10/2026 09:30:00 AM
# 5       930050  Shooting Permit  04/09/2026 06:00:00 AM
# ...        ...              ...                     ...
# 17940   677675  Shooting Permit  02/11/2023 06:00:00 AM
# 17941   677670  Shooting Permit  02/10/2023 06:00:00 AM
# 17942   677666  Shooting Permit  02/09/2023 06:00:00 AM
# 17943   677665  Shooting Permit  02/08/2023 06:00:00 AM
# 17944   889605  Shooting Permit  09/16/2025 08:00:00 AM
#
#                   EndDateTime               EnteredOn  \
# 0      04/11/2026 08:00:00 PM                     NaN
# 1      04/10/2026 11:59:00 PM                     NaN
# 2      04/11/2026 02:00:00 AM                     NaN
# 3      04/10/2026 09:30:00 PM                     NaN
# ...

# %%
df[['StartDateTime', 'ParkingHeld']]
# Out:
#                 StartDateTime  \
# 0      04/11/2026 06:30:00 AM
# 1      04/10/2026 06:00:00 AM
# 2      04/10/2026 01:00:00 PM
# 3      04/10/2026 09:30:00 AM
# 4                         NaN
# ...                       ...
# 17940  02/11/2023 06:00:00 AM
# 17941  02/10/2023 06:00:00 AM
# 17942  02/09/2023 06:00:00 AM
# 17943  02/08/2023 06:00:00 AM
# 17944  09/16/2025 08:00:00 AM
#
#                                              ParkingHeld
# 0         WEST   43 STREET between 6 AVENUE and BROADWAY
# 1      NORTH HENRY STREET between GREENPOINT AVENUE a...
# 2      PARK AVENUE between VANDERBILT AVENUE and CLIN...
# 3      WEST   24 STREET between 6 AVENUE and 5 AVENUE...
# 4      23RD ST  between HOYT AVE N  and HOYT AVE S , ...
# ...                                                  ...
# 17940   WEST   58 STREET between 10 AVENUE and 11 AVENUE
# 17941   WEST   58 STREET between 10 AVENUE and 11 AVENUE
# 17942   WEST   58 STREET between 10 AVENUE and 11 AVENUE
# ...

# %%
df_clean = df.dropna(subset=['StartDateTime'])

# %%
# The chart for StartDateTime and ParkingHeld
sns.countplot(data=df, x='StartDateTime', y='ParkingHeld')
